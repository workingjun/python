# %%
import requests
from bs4 import BeautifulSoup


page_num = 1
keyword = "노트북" #input()


while page_num<2:
        coupang_url = (
                        f"https://www.coupang.com/np/search?q={keyword}"
                        f"&channel=user&component=&eventCategory=SRP&trcid=&traid="
                        f"&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType="
                        f"&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page="
                        f"{page_num}&rocketAll=false&searchIndexingToken=1=9&backgroundColor="
                        )

        header={
                'User-Agent': (
                                "Mozilla/5.0 (Windows NT 10.0; Win64; x64) " 
                                "AppleWebKit/537.36 (KHTML, like Gecko) " 
                                "Chrome/121.0.0.0 Safari/537.36"
                                ), 
                "Accept-Language": "ko-KR,ko;q=0.9"
                }


        raw = requests.get(coupang_url, headers=header) 
        search = BeautifulSoup(raw.text, 'html.parser')


        box = search.find('ul', {'id' : 'productList'})
        all_product = box.find_all('li', {'class': 'search-product'})

        print('페이지:', page_num, "<쿠팡" + keyword + "결과>:")

        for i, product in enumerate(all_product):
                imagefind = product.find("img", {'class' : 'search-product-wrap-img'})
                if imagefind.get("data-img-src") is None:
                        imageLink = "http:" + imagefind.get('src')
                else:
                       imageLink = "http:" + imagefind.get("data-img-src")

                title = product.find('div', {'class' : 'name'})
                price = product.find('strong', {'class' : 'price-value'})
                point = product.find('span', {'class' : 'rating-total-count'})
                
                if point is None:
                       point=''

                link2 = product.find('a')['href']
                link = "https://www.coupang.com" + link2
                
                print(i, '.')
                print("이미지 링크:", imageLink)
                print('이름 : ', title.text.strip())
                print('가격 : ', price.text)
                
                if isinstance(point, str):
                        print('별점 : ', point)
                else:
                       print('별점 : ', point.text)

                print('링크:', link)
                print()
                      
        print()
        page_num+=1
# Out:
# 페이지: 1 <쿠팡노트북결과>:
# 0 .
# 이미지 링크: http://thumbnail10.coupangcdn.com/thumbnails/remote/230x230ex/image/vendor_inventory/cd86/9627e4da150302884f9bb42ec1f0a43c239c6c61faeeeff4f35b2afa2518.jpg
# 이름 :  LG그램15 코어i5(10세대/ 램 16G/ SSD 256G/ 윈도우10프로 초경량 1.09kg, 15ZB995, 코어i5, 256GB, 16GB, WIN10
# 가격 :  799,000
# 별점 :  (14)
# 링크: https://www.coupang.com/vp/products/8002847124?itemId=22295057100&vendorItemId=86681973967&sourceType=srp_product_ads&clickEventId=ff5340f0-1647-11ef-9022-c40735502a96&korePlacement=15&koreSubPlacement=1&clickEventId=ff5340f0-1647-11ef-9022-c40735502a96&korePlacement=15&koreSubPlacement=1
#
# 1 .
# 이미지 링크: http://thumbnail8.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/298805464638389-ca1c0934-3411-4ff0-a3aa-aea9cb288b28.jpg
# 이름 :  레노버 2022 아이디어패드 슬림 1 15AMN7 15.6 라이젠3 라이젠 7000 시리즈, Cloud Grey (82VG), 256GB, 8GB, Free DOS, 82VG002EKR
# 가격 :  488,900
# 별점 :  (1329)
# 링크: https://www.coupang.com/vp/products/6990469893?itemId=17107738286&vendorItemId=84281482577&pickType=COU_PICK
#
# 2 .
# 이미지 링크: http://thumbnail9.coupangcdn.com/thumbnails/remote/230x230ex/image/vendor_inventory
.
# 이미지 링크: http://thumbnail10.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/306941332537116-b675bf77-956f-47d3-9538-7545943e0eb8.jpg
# 이름 :  베이직스 2022 베이직북 14 3세대 셀러론, White, 256GB, 8GB, WIN11 Pro, BB1422SS
# 가격 :  398,000
# 별점 :  (2002)
# 링크: https://www.coupang.com/vp/products/6662026640?itemId=15294714959&vendorItemId=82515116791
#
# 22 .
# 이미지 링크: http://thumbnail7.coupangcdn.com/thumbnails/remote/230x230ex/image/vendor_inventory/04f6/ac828ade4532a6706b1d6e3872c9ce6400b88f70b3e7950d65707015ed26.jpg
# 이름 :  삼성전자 삼성노트북 NT200B5C/i5-3210/4G/SSD128G/DVD멀티/15.6/1600*900/윈도우10/2.3kg/무상보증1년, NT200B5C, WIN10 Pro, 4GB, 128GB, 코어i5, 블랙
# 가격 :  179,000
# 별점 :  (93)
# 링크: https://www.coupang.com/vp/products/6431304215?itemId=13881662519&vendorItemId=81135207478
#
# 23 .
# 이미지 링크: http://thumbnail8.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/3564201908198878-6bf3674c-f1fc-4d81-b45d-f2906635d14a.jpg
# 이름 :  LG전자 2021 울트라 PC 14 셀러론, 화이트, 128GB, 4GB, WIN11 Home, 14U30P-LE12K
# 가격 :  510,000
# 별점 :  (484)
# 링크: https://www.coupang.com/vp/products/6372763434?itemId=19064151414&vendorItemId=86187002175
#
# 24 .
# 이미지 링크: http://thumbnail7.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/3561561544309485-96a93cbb-2e44-4ab7-be63-9290bd7b37df.jpg
# 이름 :  LG전자 2023 그램15 코어i5 인텔 13세대, 스노우 화이트, 256GB, 16GB, WIN11 Home, 15Z90RU-GAOWK
# 가격 :  1,550,000
# 별점 :  (945)
# 링크: https://www.coupang.com/vp/products/7709148497?itemId=20660237250&vendorItemId=86160350574
#
# 25 .
# 이미지 링크: http://thumbnail7.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/803243108162396-87501690-44d7-41fd-94b3-ac54d352bde6.png
# 이름 :  마이크로소프트 2022 서피스 랩탑5 13.5 코어i5 인텔 12세대, 블랙, 256GB, 16GB, WIN11 Home, XFK-00003
# 가격 :  1,488,000
# 별점 :  (444)
# 링크: https://www.coupang.com/vp/products/7685556825?itemId=18713253519&vendorItemId=85846333952&sourceType=srp_product_ads&clickEventId=ff538f10-1647-11ef-9f4f-ce0b6eb81107&korePlacement=15&koreSubPlacement=21&clickEventId=ff538f10-1647-11ef-9f4f-ce0b6eb81107&korePlacement=15&koreSubPlacement=21
#
# 26 .
# 이미지 링크: http://thumbnail9.coupangcdn.com/thumbnails/remote/230x230ex/image/vendor_inventory/a253/0827c850673806a0506b62deb9c5c896448c0c60d0e6c84da56bfec8cc3e.jpg
# 이름 :  [삼성전자] 갤럭시북2 NT550XEZ-A38A [실버] [기본제품], WIN11 Pro, 8GB, 256GB, 코어i3
# 가격 :  639,000
# 별점 :  (2)
# 링크: https://www.coupang.com/vp/products/7969944365?itemId=22069895743&vendorItemId=89116995663&sourceType=srp_product_ads&clickEventId=ff538f10-1647-11ef-a646-bc779beb099a&korePlacement=15&koreSubPlacement=22&clickEventId=ff538f10-1647-11ef-a646-bc779beb099a&korePlacement=15&koreSubPlacement=22
#
# 27 .
# 이미지 링크: http://thumbnail9.coupangcdn.com/thumbnails/remote/230x230ex/image/rs_quotation_api
.
# 이미지 링크: http://thumbnail7.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/2023/11/28/10/0/574b91e9-9a00-44c2-9035-46385e1cfbf0.jpg
# 이름 :  레노버 2023 아이디어패드 슬림 3 15IAH8 코어i5 인텔 12세대, ARCTIC GREY, 512GB, 16GB, Free DOS, 83ER0060KR
# 가격 :  701,680
# 별점 :  (224)
# 링크: https://www.coupang.com/vp/products/7743816755?itemId=20841101281&vendorItemId=87908831614
#
# 59 .
# 이미지 링크: http://thumbnail7.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/2023/09/01/11/2/08522b62-9c4a-4745-8bcd-80638cc861fb.jpg
# 이름 :  HP 2023 노트북 15s 코어i5 인텔 12세대, 화이트, 512GB, 16GB, Win11 HOME, 15s-fq5304TU
# 가격 :  589,130
# 별점 :  (2)
# 링크: https://www.coupang.com/vp/products/8072722173?itemId=22729808446&vendorItemId=87223810100

# %%
header={
        'User-Agent': (
                        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) " 
                        "AppleWebKit/537.36 (KHTML, like Gecko) " 
                        "Chrome/121.0.0.0 Safari/537.36"
                        ), 
        "Accept-Language": "ko-KR,ko;q=0.9"
       }

header
# Out:
# {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)AppleWebKit/537.36 (KHTML, like Gecko)Chrome/121.0.0.0 Safari/537.36',
#  'Accept-Language': 'ko-KR,ko;q=0.9'}

# %%
point=''
isinstance(point, str)
# Out:
# True

# %%
from tkinter import *
from PIL import Image, ImageTk
from urllib.request import urlopen
from io import BytesIO
import requests
from bs4 import BeautifulSoup

index_num = 0
product_num = 1

def delete_and_insert():
    global imageLink_list, title_list, price_list, point_list, link_list

    display1.delete(1.0, END)
    display2.delete(1.0, END)
    display3.delete(1.0, END)
    display4.delete(1.0, END)

    display1.insert(1.0, title_list[index_num])
    display2.insert(1.0, price_list[index_num])
    display3.insert(1.0, point_list[index_num])
    display4.insert(1.0, link_list[index_num])

def img_insert():
    global link_list

    image_url = imageLink_list[index_num]

    with urlopen(image_url) as response:
        image_data = response.read()

        image = Image.open(BytesIO(image_data))
        photo = ImageTk.PhotoImage(image)

    label1.configure(image=photo)
    label1.image=photo

def keyword_submit():
    keyword_got = keyword_entry.get()
    keyword_got = f"<{keyword_got}의 쇼핑 목록>"
    information_list.configure(text=keyword_got)
    
def command_current():
    global index_num

    index_num=0

    img_insert()
    delete_and_insert()

def clickNext():
    global index_num, imageLink_list
        
    index_num+=1
    if index_num>len(imageLink_list)-1:
        index_num=0

    img_insert()
    delete_and_insert()

    
def clickPrev():
    global index_num, imageLink_list

    index_num-=1
    if index_num<0:
        index_num = len(imageLink_list)-1

    img_insert()
    delete_and_insert()

def search_action():
    global imageLink_list, title_list, price_list, point_list, link_list, product_num

    link_list = []
    imageLink_list = []
    title_list = []
    price_list = []
    point_list = []

    search_query = keyword_entry.get()
    page_num = int(page_num_entry.get())
    
    coupang_url = (
                f"https://www.coupang.com/np/search?q={search_query}"
                f"&channel=user&component=&eventCategory=SRP&trcid=&traid="
                f"&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType="
                f"&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page="
                f"{page_num}&rocketAll=false&searchIndexingToken=1=9&backgroundColor="
                )
    header={
            'User-Agent': (
                        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) " 
                        "AppleWebKit/537.36 (KHTML, like Gecko) " 
                        "Chrome/121.0.0.0 Safari/537.36"
                        ), 
            "Accept-Language": "ko-KR,ko;q=0.9"
            }
    
    raw = requests.get(coupang_url, headers=header) 
    search = BeautifulSoup(raw.text, 'html.parser')

    box = search.find('ul', {'id' : 'productList'})
    all_product = box.find_all('li', {'class': 'search-product'})

    for product in all_product:
        imagefind = product.find("img", {'class' : 'search-product-wrap-img'})

        if imagefind.get("data-img-src") is None:
            imageLink = "http:" + imagefind.get('src')
        else:
            imageLink = "http:" + imagefind.get("data-img-src")

        title = product.find('div', {'class' : 'name'})
        price = product.find('strong', {'class' : 'price-value'})
        point = product.find('span', {'class' : 'rating-total-count'})
        
        if point is None:
                point=''

        link2 = product.find('a')['href']
        link = "https://www.coupang.com" + link2

        imageLink_list.append(imageLink)

        title_text = f"{product_num}. {title.text.strip()}"

        title_list.append(title_text)
        price_list.append(price.text)

        if isinstance(point, str):
                point_list.append(point)
        else:
                point_list.append(point.text)
        
        link_list.append(link)    
        product_num += 1
        
    keyword_submit()
    command_current()


win=Tk()
win.title("coupang shopping")       
win.geometry("580x800")

information0 = Label(win, text=f"<쿠팡 쇼핑 시스템>\n")         
information0.grid(column=1, row=0)

information1 = Label(win, text="아래 검색어를 입력하세요.")
information2 = Label(win, text="페이지 수 입력하세요.")

information1.grid(column=0, row=1)
information2.grid(column=1, row=1)

keyword_entry = Entry(win)
page_num_entry = Entry(win)

keyword_entry.grid(column=0, row=2)
page_num_entry.grid(column=1, row=2)

search_button = Button(win, text="검색", command=search_action)
search_button.grid(column=2, row=2, columnspan=3)

btnPrev=Button(win, text="<<이전", command=clickPrev)
btnNext=Button(win, text="다음>>", command=clickNext)

information_list = Label(win, text="<검색어의 쇼핑 목록>")
information_list.grid(column=1, row=3)

label1 = Label(win)
display1 = Text(win, width=80, height=3, borderwidth=5)
display2 = Text(win, width=80, height=3, borderwidth=5)
display3 = Text(win, width=80, height=3, borderwidth=5)
display4 = Text(win, width=80, height=3, borderwidth=5)

information3 = Label(win, text=(
                                f"<사용 설명서>\n\n"
                                f"첫 번째 빈 항목에 검색어를 입력하고\n"
                                f"두 번째 빈 항목에 원하는 페이지를 입력하세요\n\n"
                                f"한 페이지당 보통 50개~70개 정도 검색 가능하며\n"
                                f"그 후 검색 버튼을 누르면 페이지마다 쇼핑 목록을 볼 수 있습니다\n"
                                )
                    )

label1.grid(column=1, row=4)

display1.grid(column=0, row=5, columnspan=4)
display2.grid(column=0, row=6, columnspan=4)
display3.grid(column=0, row=7, columnspan=4)
display4.grid(column=0, row=8, columnspan=4)

btnPrev.grid(column=0, row=9)
btnNext.grid(column=2, row=9)

information3.grid(column=1, row=10)

win.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\kimju\anaconda3\envs\cupang\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "C:\Users\kimju\AppData\Local\Temp\ipykernel_68\2280864622.py", line 129, in search_action
#     price_list.append(price.text)
# AttributeError: 'NoneType' object has no attribute 'text'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\kimju\anaconda3\envs\cupang\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "C:\Users\kimju\AppData\Local\Temp\ipykernel_68\2280864622.py", line 129, in search_action
#     price_list.append(price.text)
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
price_list
# Out:
# []
